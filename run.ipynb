# %%
from stock_fetcher import fetch_prices

fetch_prices('minevini_buy_tickers.csv')
# Out:
# CSV 파일 minevini_buy_tickers_recent_prices_08-18.csv 저장 완료!

# %%
import plot
plot.plot_portfolio_performance('minevini_buy_tickers_recent_prices_08-18.csv', 'minevini_buy_tickers.csv')
